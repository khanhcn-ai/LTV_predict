# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import minimize
import seaborn as sns
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
import optuna
import lightgbm as lgb
import catboost as cb
from sklearn.linear_model import ElasticNet
import shap
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import PolynomialFeatures
from ray.tune.search.sample import Integer as Int
from ray.tune.search.sample import Float as Real
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
import logging
optuna.logging.set_verbosity(logging.WARNING)
from sklearn.preprocessing import RobustScaler
from numpy.random import dirichlet
from pandas.api.types import is_categorical_dtype, is_bool_dtype, is_float_dtype, is_integer_dtype
from sklearn.preprocessing import PowerTransformer
from optuna.integration import XGBoostPruningCallback
from autogluon.tabular import TabularPredictor
from autogluon.core.metrics import make_scorer

# %%
def apply_mixup_train_data(X_train_df, y_train_df, augmentation_factor=1.0, random_state=42):
    if augmentation_factor <= 0:
        return X_train_df.copy(), y_train_df.copy()

    X = X_train_df.reset_index(drop=True)
    y = y_train_df.reset_index(drop=True)
    N = len(X)
    if N == 0:
        return X.copy(), y.copy()

    N_aug = int(N * augmentation_factor)
    if N_aug <= 0:
        return X.copy(), y.copy()

    ohe_groups = []
    ohe_cols = set()

    rng = np.random.default_rng(random_state)
    idx_A = rng.integers(0, N, size=N_aug)
    idx_B = (idx_A + (rng.integers(1, N, size=N_aug) if N > 1 else 0)) % max(N, 1)
    lam = rng.beta(1.0, 1.0, size=N_aug).reshape(-1, 1)
    pickA = (lam.ravel() > 0.5)

    cols = list(X.columns)
    
    float_cols = [c for c in cols if is_float_dtype(X[c].dtype)] 
    int_cols = [c for c in cols if is_integer_dtype(X[c].dtype)] 
    bool_cols = [c for c in cols if is_bool_dtype(X[c].dtype)]
    
    int_cols = [c for c in int_cols if c not in bool_cols and c not in float_cols]
    
    handled_cols = set(float_cols) | set(int_cols) | set(bool_cols) 
    other_cols = [c for c in cols if c not in handled_cols]

    new_cols = {}

    if float_cols:
        A = X[float_cols].to_numpy()[idx_A]
        B = X[float_cols].to_numpy()[idx_B]
        M = lam * A + (1.0 - lam) * B
        for j, c in enumerate(float_cols):
            new_cols[c] = M[:, j].astype(X[c].dtype, copy=False)

    if int_cols:
        A = X[int_cols].astype('float64', copy=False).to_numpy()[idx_A]
        B = X[int_cols].astype('float64', copy=False).to_numpy()[idx_B]
        M = lam * A + (1.0 - lam) * B
        R = np.rint(M)
        mins = X[int_cols].astype('float64', copy=False).min().to_numpy()
        maxs = X[int_cols].astype('float64', copy=False).max().to_numpy()
        C = np.clip(R, mins, maxs)
        for j, c in enumerate(int_cols):
            new_cols[c] = C[:, j].astype(X[c].dtype, copy=False)

    if bool_cols:
        A = X[bool_cols].to_numpy()[idx_A]
        B = X[bool_cols].to_numpy()[idx_B]
        M = np.where(pickA[:, None], A, B)
        for j, c in enumerate(bool_cols):
            new_cols[c] = M[:, j].astype(X[c].dtype, copy=False)

    if other_cols:
        A = X[other_cols].to_numpy(dtype=object)[idx_A]
        B = X[other_cols].to_numpy(dtype=object)[idx_B]
        M = np.where(pickA[:, None], A, B)
        for j, c in enumerate(other_cols):
            new_cols[c] = M[:, j]

    X_new = pd.DataFrame({c: new_cols[c] for c in cols}, columns=cols)

    yA = y.to_numpy(dtype=np.float64)[idx_A]
    yB = y.to_numpy(dtype=np.float64)[idx_B]
    y_new = lam * yA + (1.0 - lam) * yB
    y_new_df = pd.DataFrame(y_new, columns=y.columns)

    X_aug = pd.concat([X, X_new], ignore_index=True)
    y_aug = pd.concat([y, y_new_df], ignore_index=True)
    return X_aug, y_aug

def target_encode_cv(X_train_df, y_train_df, X_test_df, categorical_col, cv):
    
    X_train_df = X_train_df.reset_index(drop=True)
    y_train_df = y_train_df.reset_index(drop=True)
    X_test_df = X_test_df.reset_index(drop=True)
    
    target_col = y_train_df.columns[0]
    
    oof_encoded = np.zeros(X_train_df.shape[0])
    test_encoded = np.zeros(X_test_df.shape[0])
    
    global_mean = y_train_df[target_col].mean()
    
    for fold, (train_idx, val_idx) in enumerate(cv.split(X_train_df, y_train_df)):
        
        X_train_fold = X_train_df.iloc[train_idx]
        y_train_fold = y_train_df.iloc[train_idx]
        
        X_val_fold = X_train_df.iloc[val_idx]
        
        mean_encoding_map = y_train_fold.groupby(X_train_fold[categorical_col])[target_col].mean()
        
        oof_encoded[val_idx] = X_val_fold[categorical_col].map(mean_encoding_map).fillna(global_mean).values
        
        test_encoded_fold = X_test_df[categorical_col].map(mean_encoding_map).fillna(global_mean).values
        test_encoded += test_encoded_fold / cv.n_splits

    X_train_df[categorical_col] = oof_encoded
    X_test_df[categorical_col] = test_encoded
    
    return X_train_df, X_test_df

def generate_oof_elasticnet(X_train_df, y_train_df, X_test_df, cv, random_state=42):
    
    X_train_df = X_train_df.copy()
    X_test_df = X_test_df.copy()

    X_train_arr = X_train_df.values
    y_train_arr = y_train_df.values.flatten()
    X_test_arr = X_test_df.values

    oof_predictions = np.zeros(X_train_arr.shape[0])
    test_predictions = np.zeros(X_test_arr.shape[0])

    scaler = StandardScaler()

    for fold, (train_idx, val_idx) in enumerate(cv.split(X_train_arr, y_train_arr)):

        model = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=random_state)

        X_train_fold, X_val_fold = X_train_arr[train_idx], X_train_arr[val_idx]
        y_train_fold = y_train_arr[train_idx]

        X_train_scaled = scaler.fit_transform(X_train_fold)

        X_val_scaled = scaler.transform(X_val_fold)
        X_test_scaled = scaler.transform(X_test_arr)

        model.fit(X_train_scaled, y_train_fold)

        oof_predictions[val_idx] = model.predict(X_val_scaled)

        test_predictions += model.predict(X_test_scaled) / cv.n_splits

    oof_col_name = 'OOF_ElasticNet'

    X_train_df[oof_col_name] = oof_predictions
    X_test_df[oof_col_name] = test_predictions

    return X_train_df, X_test_df

# %%
df_ori = pd.read_csv('data/raw_2025-04-01_2025-05-31_puzzle_com.twisted.rope.tangle.csv')

df = df_ori[['roas_d0','roas_d1','roas_d2','roas_d3',
        'cumulative_revenue_d0','cumulative_revenue_d1','cumulative_revenue_d2','cumulative_revenue_d3',
        'daily_revenue_d0','daily_revenue_d1','daily_revenue_d2',
        'unique_users_d0','unique_users_d1','unique_users_d2','unique_users_d3','daily_revenue_d3','cost',
        'ltv_d0', 'ltv_d1', 'ltv_d2', 'ltv_d3']].copy()
df['ltv_mean'] = df[['ltv_d0', 'ltv_d1', 'ltv_d2', 'ltv_d3']].mean(axis=1)
df['roas_mean'] = df[['roas_d0','roas_d1','roas_d2','roas_d3']].mean(axis=1)
df['cumulative_revenue_mean'] = df[['cumulative_revenue_d0','cumulative_revenue_d1','cumulative_revenue_d2','cumulative_revenue_d3']].mean(axis=1)

df['ltv_std'] = df[['ltv_d0', 'ltv_d1', 'ltv_d2', 'ltv_d3']].std(axis=1)
df['roas_std'] = df[['roas_d0','roas_d1','roas_d2','roas_d3']].std(axis=1)
df['cumulative_revenue_std'] = df[['cumulative_revenue_d0','cumulative_revenue_d1','cumulative_revenue_d2','cumulative_revenue_d3']].std(axis=1)

df['ltv_growth'] = (df['ltv_d3'] - df['ltv_d0']) / (3 + 1e-9)
df['cumulative_revenue_growth'] = df['cumulative_revenue_d3'] - df['cumulative_revenue_d0']

df['revenue_acceleration'] = df['daily_revenue_d3'] - df['daily_revenue_d2'] - df['daily_revenue_d1'] + df['daily_revenue_d0']
df['user_acceleration'] = df['unique_users_d3'] - df['unique_users_d2'] - df['unique_users_d1'] + df['unique_users_d0']

df['roas_trend'] = df['roas_d3'] - df['roas_d0']
df['ltv_roas_ratio'] = df['ltv_d3'] / df['roas_d3']

df['ltv_slope_d0_d1'] = df['ltv_d1'] - df['ltv_d0']
df['ltv_slope_d1_d2'] = df['ltv_d2'] - df['ltv_d1']
df['ltv_slope_d2_d3'] = df['ltv_d3'] - df['ltv_d2']
df['ARPU_d0'] = df['daily_revenue_d0'] / df['unique_users_d0']
df['ARPU_d1'] = df['daily_revenue_d1'] / df['unique_users_d1']
df['ARPU_d2'] = df['daily_revenue_d2'] / df['unique_users_d2']
df['ARPU_d3'] = df['daily_revenue_d3'] / df['unique_users_d3']
df['retention_d1'] = df['unique_users_d1'] / df['unique_users_d0']
df['retention_d2'] = df['unique_users_d2'] / df['unique_users_d0']
df['retention_d3'] = df['unique_users_d3'] / df['unique_users_d0']

df['ltv_acceleration'] = df['ltv_slope_d2_d3'] - df['ltv_slope_d1_d2']
df['roas_slope_d0_d1'] = df['roas_d1'] - df['roas_d0']
df['roas_slope_d1_d2'] = df['roas_d2'] - df['roas_d1']
df['roas_slope_d2_d3'] = df['roas_d3'] - df['roas_d2']
df['roas_acceleration'] = df['roas_slope_d2_d3'] - df['roas_slope_d1_d2']
df['is_ltv_slowing_down'] = (df['ltv_acceleration'] < 0).astype(int)
df['is_roas_slowing_down'] = (df['roas_acceleration'] < 0).astype(int)

df['ltv_gain'] = df['ltv_d3'] - df['ltv_d0']
df['cumulative_users_d3'] = df['unique_users_d0'] + df['unique_users_d1'] + df['unique_users_d2'] + df['unique_users_d3']
df['ARPU_cumulative_d3'] = df['cumulative_revenue_d3'] / df['cumulative_users_d3']
df['ARPU_trend'] = (df['daily_revenue_d3'] / (df['unique_users_d3'] + 1e-9)) - (df['daily_revenue_d0'] / (df['unique_users_d0'] + 1e-9))
df['Payback_Velocity'] = (df['cumulative_revenue_d3'] / df['cost']) / 4
df['Acceleration_Ratio'] = df['revenue_acceleration'] / (df['user_acceleration'] + 1e-9)
df['CAC'] = df['cost'] / df['cumulative_users_d3']
df['ROAS_CV'] = df['roas_std'] / (df['roas_mean'] + 1e-9)
df['ERTI'] = df['cumulative_users_d3'] / df['cost']
df['LTV_CAC'] = df['ltv_d3'] / df['CAC']

df['daily_to_cumulative_revenue_ratio_d3'] = df['daily_revenue_d3'] / (df['cumulative_revenue_d3'] + 1e-9)
df['d0_cohort_value_d3'] = df['cumulative_revenue_d3'] / (df['unique_users_d0'] + 1e-9)
df['user_growth_d3_vs_d0'] = df['unique_users_d3'] / (df['unique_users_d0'] + 1e-9)
df['cost_per_revenue_d3'] = df['cost'] / (df['cumulative_revenue_d3'] + 1e-9)
df['arpu_d3_x_payback'] = df['ARPU_cumulative_d3'] * df['Payback_Velocity']
df['LTV_CV'] = df['ltv_std'] / (df['ltv_mean'] + 1e-9)
df['LTV_CAC_Trend'] = df['LTV_CAC'] * df['ARPU_trend']
df['Cost_LTV_Mean'] = df['cost'] * df['ltv_mean']
df['Payback_Accel'] = df['Payback_Velocity'] * df['ltv_acceleration']
df['ROAS_Std_Weighted'] = df['roas_std'] * df['LTV_CAC']
df['Daily_to_Cumul_LTV'] = df['daily_to_cumulative_revenue_ratio_d3'] * df['ltv_d3']

power_cols_base = ['ltv_mean', 'cost', 'LTV_CAC', 'Payback_Velocity', 'ltv_acceleration', 'roas_mean','ARPU_trend']
poly_transformer = PolynomialFeatures(degree=2, include_bias=False)
X_poly_base = df[power_cols_base]
X_poly_transformed = poly_transformer.fit_transform(X_poly_base)
new_poly_names = poly_transformer.get_feature_names_out(input_features=power_cols_base)
df_poly = pd.DataFrame(X_poly_transformed, columns=new_poly_names, index=df.index)
df = pd.concat([df.drop(columns=power_cols_base), df_poly], axis=1)
cv = KFold(n_splits=5, shuffle=True, random_state=42)
ltv = df_ori.filter(like='ltv_d')
ltv = ltv[sorted(ltv.columns, key=lambda x: int(x[5:]))]
ltv = ltv.iloc[: , 4:]
ltv_cols = ltv.columns.to_list()
df = df.fillna(0)
eps = 1e-9
df = pd.concat([df, ltv], axis=1)

df.shape
# Out:
# (509, 156)

# %%
df = df.drop(columns=['daily_revenue_d0',
 'LTV_CAC ARPU_trend',
 'ltv_mean Payback_Velocity',
 'LTV_CAC roas_mean',
 'LTV_CAC Payback_Velocity',
 'roas_mean',
 'ARPU_cumulative_d3',
 'cost Payback_Velocity',
 'cost',
 'revenue_acceleration',
 'LTV_CV',
 'Payback_Velocity roas_mean',
 'Payback_Velocity',
 'cumulative_revenue_d2',
 'cumulative_revenue_growth',
 'Payback_Velocity ARPU_trend',
 'LTV_CAC^2',
 'cumulative_users_d3',
 'cumulative_revenue_mean',
 'Payback_Velocity ltv_acceleration',
 'roas_mean^2',
 'cost roas_mean',
 'cumulative_revenue_std',
 'cost_per_revenue_d3',
 'cumulative_revenue_d3',
 'ltv_mean cost',
 'ltv_acceleration roas_mean',
 'cumulative_revenue_d1',
 'cost^2',
 'is_ltv_slowing_down',
 'LTV_CAC_Trend',
 'Payback_Velocity^2',
 'is_roas_slowing_down',
 'arpu_d3_x_payback',
 'daily_revenue_d2',
 'daily_revenue_d3',
 'roas_mean ARPU_trend',
 'cost LTV_CAC',
 'LTV_CAC ltv_acceleration',
 'Payback_Accel',
 'roas_trend',
 'ROAS_Std_Weighted'])#

# %%
wide_id_cols = [c for c in df.columns if c not in ltv_cols]

X_wide = df[wide_id_cols]
y_wide = df[ltv_cols]
X_train_wide, X_test_wide, y_train_wide, y_test_wide = train_test_split(X_wide, y_wide, test_size=0.2, random_state=42)

df_train = pd.concat([X_train_wide.reset_index(drop=True), y_train_wide.reset_index(drop=True)], axis=1)
df_test  = pd.concat([X_test_wide.reset_index(drop=True),  y_test_wide.reset_index(drop=True)],  axis=1)

id_vars_train = [c for c in df_train.columns if c not in ltv_cols]
id_vars_test  = [c for c in df_test.columns  if c not in ltv_cols]

df_train_long = pd.melt(df_train, id_vars=id_vars_train, value_vars=ltv_cols, var_name='Day', value_name='LTV')
df_train_long['Day'] = df_train_long['Day'].str.replace('ltv_d', '').astype(int)

df_test_long = pd.melt(df_test, id_vars=id_vars_test, value_vars=ltv_cols, var_name='Day', value_name='LTV')
df_test_long['Day'] = df_test_long['Day'].str.replace('ltv_d', '').astype(int)

features_long = [c for c in df_train_long.columns if c != 'LTV']
target = ['LTV']

X_train = df_train_long[features_long].reset_index(drop=True)
y_train = df_train_long[target].reset_index(drop=True)
X_test  = df_test_long[features_long].reset_index(drop=True)
y_test  = df_test_long[target].reset_index(drop=True)

# %%
features = X_train.columns.tolist()
preprocessor_X = PowerTransformer(method='yeo-johnson', standardize=False)
preprocessor_y = PowerTransformer(method='yeo-johnson', standardize=False)

#X_train = pd.DataFrame(preprocessor_X.fit_transform(X_train), columns=features)
#X_test = pd.DataFrame(preprocessor_X.transform(X_test), columns=features)
#y_train_transformed = pd.DataFrame(preprocessor_y.fit_transform(y_train), columns=['LTV'])
#y_test_transformed = pd.DataFrame(preprocessor_y.transform(y_test), columns=['LTV'])

train_data = pd.concat([X_train, y_train], axis=1) 
test_data = pd.concat([X_test, y_test], axis=1)

# %%
def nae_score_func(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    eps = 1e-9 
    return 100 * np.mean(
        np.abs(y_true - y_pred) / (np.abs(y_true) + eps)
    )

custom_nae = make_scorer(
    name='NAE',
    score_func=nae_score_func,
    greater_is_better=False,
    needs_proba=False
)

# %%
predictor = TabularPredictor(
    label="LTV", 
    eval_metric=custom_nae,
    path='./AutoGluon_LTV_D60'
)

predictor.fit(
    train_data, 
    presets='best_quality',
    time_limit=3600,
    ag_args_ensemble={'fold_fitting_strategy': 'sequential_local'},
    ds_args={'enable_ray_logging': False}
)

print("\n--- AutoGluon đã hoàn tất huấn luyện! ---")
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./AutoGluon_LTV_D60"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.12.6
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          16
# Memory Avail:       4.77 GB / 13.86 GB (34.5%)
# Disk Space Avail:   49.23 GB / 125.01 GB (39.4%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Logs will not be shown until this process is complete (enable_ray_logging=False). You can experimentally enable logging by specifying `ds_args={'enable_ray_logging': True}`.
# C:\Users\namkh\AppData\Roaming\Python\Python312\site-packages\autogluon\tabular\predictor\predictor.py:1444: UserWarning: Failed to use ray for memory safe fits. Falling back to normal fit. Error: Exception('The current node timed out during startup. This could happen because some of the Ray processes failed to startup.')
#   stacked_overfitting = self._sub_fit_memory_save_wrapper(
# 		Context path: "e:\Thực tập\ML cho Marketing\AutoGluon_LTV_D60\ds_sub_fit\sub_fit_ho"
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 838s
# AutoGluon will save models to "e:\Thực tập\ML cho Marketing\AutoGluon_LTV_D60\ds_sub_fit\sub_fit_ho"
# Train Data Rows:    20621
# Train Data Columns: 58
# Label Column:       LTV
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4470.76 MB
# 	Train Data (Original)  Memory Usage: 9.13 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['roas_d0', 'roas_d1', 'roas_d2', 'roas_d3', 'cumulative_revenue_d0', ...]
# 		('int', [])   :  6 | ['unique_users_d0', 'unique_users_d1', 'unique_users_d2', 'unique_users_d3', 'user_acceleration', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['roas_d0', 'roas_d1', 'roas_d2', 'roas_d3', 'cumulative_revenue_d0', ...]
# 		('int', [])   :  6 | ['unique_users_d0', 'unique_users_d1', 'unique_users_d2', 'unique_users_d3', 'user_acceleration', ...]
# 	0.2s = Fit runtime
# 	58 features in original data used to generate 58 features in processed data.
# 	Train Data (Processed) Memory Usage: 9.13 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 0.24s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'NAE'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 558.19s of the 837.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# [1000]	valid_set's l2: 4.44143e-05	valid_set's NAE: -1.79149
# [2000]	valid_set's l2: 2.8829e-05	valid_set's NAE: -1.2437
# [3000]	valid_set's l2: 2.27414e-05	valid_set's NAE: -1.05478
# [4000]	valid_set's l2: 2.01099e-05	valid_set's NAE: -0.974154
# [5000]	valid_set's l2: 1.83753e-05	valid_set's NAE: -0.930485
# [6000]	valid_set's l2: 1.75433e-05	valid_set's NAE: -0.9016
# [7000]	valid_set's l2: 1.68057e-05	valid_set's NAE: -0.881215
# [8000]	valid_set's l2: 1.63229e-05	valid_set's NAE: -0.863634
# [9000]	valid_set's l2: 1.58702e-05	valid_set's NAE: -0.850098
# [10000]	valid_set's l2: 1.54429e-05	valid_set's NAE: -0.84256
# [1000]	valid_set's l2: 5.26871e-05	valid_set's NAE: -1.82847
# [2000]	valid_set's l2: 3.51421e-05	valid_set's NAE: -1.30492
# [3000]	valid_set's l2: 3.11622e-05	valid_set's NAE: -1.12021
# [4000]	valid_set's l2: 2.94484e-05	valid_set's NAE: -1.02189
# [5000]	valid_set's l2: 2.80146e-05	valid_set's NAE: -0.954643
# [6000]	valid_set's l2: 2.73604e-05	valid_set's NAE: -0.90725
# [7000]	valid_set's l2: 2.65203e-05	valid_set's NAE: -0.875138
# [8000]	valid_set's l2: 2.58887e-05	valid_set's NAE: -0.851624
# [9000]	valid_set's l2: 2.532e-05	valid_set's NAE: -0.834513
# [10000]	valid_set's l2: 2.46995e-05	valid_set's NAE: -0.818215
# [1000]	valid_set's l2: 6.32294e-05	valid_set's NAE: -1.82412
# [2000]	valid_set's l2: 4.41772e-05	valid_set's NAE: -1.2883
# [3000]	valid_set's l2: 3.73141e-05	valid_set's NAE: -1.10362
# [4000]	valid_set's l2: 3.38706e-05	valid_set's NAE: -1.01288
# [5000]	valid_set's l2: 3.13671e-05	valid_set's NAE: -0.956704
# [6000]	valid_set's l2: 3.00665e-05	valid_set's NAE: -0.911411
# [7000]	valid_set's l2: 2.9188e-05	valid_set's NAE: -0.876441
# [8000]	valid_set's l2: 2.83638e-05	valid_set's NAE: -0.849663
# [9000]	valid_set's l2: 2.73591e-05	valid_set's NAE: -0.828606
# [10000]	valid_set's l2: 2.64997e-05	valid_set's NAE: -0.809614
# [1000]	valid_set's l2: 4.16633e-05	valid_set's NAE: -1.79561
# [2000]	valid_set's l2: 2.52513e-05	valid_set's NAE: -1.29216
# [3000]	valid_set's l2: 1.99782e-05	valid_set's NAE: -1.08909
# [4000]	valid_set's l2: 1.71895e-05	valid_set's NAE: -0.976636
# [5000]	valid_set's l2: 1.54593e-05	valid_set's NAE: -0.907499
# [6000]	valid_set's l2: 1.43493e-05	valid_set's NAE: -0.859625
# [7000]	valid_set's l2: 1.35242e-05	valid_set's NAE: -0.823422
# [8000]	valid_set's l2: 1.29417e-05	valid_set's NAE: -0.795611
# [9000]	valid_set's l2: 1.24883e-05	valid_set's NAE: -0.774054
# [10000]	valid_set's l2: 1.21447e-05	valid_set's NAE: -0.75834
# [1000]	valid_set's l2: 4.90811e-05	valid_set's NAE: -1.74625
# [2000]	valid_set's l2: 2.93503e-05	valid_set's NAE: -1.25998
# [3000]	valid_set's l2: 2.33703e-05	valid_set's NAE: -1.07159
# [4000]	valid_set's l2: 2.03408e-05	valid_set's NAE: -0.971152
# [5000]	valid_set's l2: 1.85014e-05	valid_set's NAE: -0.905022
# [6000]	valid_set's l2: 1.7449e-05	valid_set's NAE: -0.860603
# [7000]	valid_set's l2: 1.66113e-05	valid_set's NAE: -0.826971
# [8000]	valid_set's l2: 1.60168e-05	valid_set's NAE: -0.804372
# [9000]	valid_set's l2: 1.55857e-05	valid_set's NAE: -0.786825
# [10000]	valid_set's l2: 1.51898e-05	valid_set's NAE: -0.772164
# [1000]	valid_set's l2: 4.952e-05	valid_set's NAE: -1.80724
# [2000]	valid_set's l2: 3.04088e-05	valid_set's NAE: -1.27986
# [3000]	valid_set's l2: 2.36519e-05	valid_set's NAE: -1.1028
# [4000]	valid_set's l2: 2.03757e-05	valid_set's NAE: -1.00702
# [5000]	valid_set's l2: 1.8494e-05	valid_set's NAE: -0.941762
# [6000]	valid_set's l2: 1.71711e-05	valid_set's NAE: -0.898718
# [7000]	valid_set's l2: 1.62756e-05	valid_set's NAE: -0.868633
# [8000]	valid_set's l2: 1.56627e-05	valid_set's NAE: -0.848304
# [9000]	valid_set's l2: 1.51083e-05	valid_set's NAE: -0.833907
# [10000]	valid_set's l2: 1.47312e-05	valid_set's NAE: -0.820705
# [1000]	valid_set's l2: 3.90497e-05	valid_set's NAE: -1.79144
# [2000]	valid_set's l2: 2.36926e-05	valid_set's NAE: -1.28984
# [3000]	valid_set's l2: 1.87301e-05	valid_set's NAE: -1.10452
# [4000]	valid_set's l2: 1.62309e-05	valid_set's NAE: -0.993188
# [5000]	valid_set's l2: 1.47179e-05	valid_set's NAE: -0.928358
# [6000]	valid_set's l2: 1.36522e-05	valid_set's NAE: -0.881636
# [7000]	valid_set's l2: 1.29078e-05	valid_set's NAE: -0.848166
# [8000]	valid_set's l2: 1.23284e-05	valid_set's NAE: -0.8222
# [9000]	valid_set's l2: 1.19191e-05	valid_set's NAE: -0.803425
# [10000]	valid_set's l2: 1.15322e-05	valid_set's NAE: -0.785273
# [1000]	valid_set's l2: 4.32678e-05	valid_set's NAE: -1.72114
# [2000]	valid_set's l2: 2.76808e-05	valid_set's NAE: -1.26673
# [3000]	valid_set's l2: 2.27302e-05	valid_set's NAE: -1.07388
# [4000]	valid_set's l2: 2.00559e-05	valid_set's NAE: -0.975273
# [5000]	valid_set's l2: 1.84889e-05	valid_set's NAE: -0.914163
# [6000]	valid_set's l2: 1.7356e-05	valid_set's NAE: -0.870703
# [7000]	valid_set's l2: 1.66069e-05	valid_set's NAE: -0.84238
# [8000]	valid_set's l2: 1.60079e-05	valid_set's NAE: -0.817853
# [9000]	valid_set's l2: 1.55908e-05	valid_set's NAE: -0.799161
# [10000]	valid_set's l2: 1.52434e-05	valid_set's NAE: -0.783568
# 	-0.7987	 = Validation score   (-NAE)
# 	134.63s	 = Training   runtime
# 	2.43s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 418.13s of the 697.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# [1000]	valid_set's l2: 3.33408e-05	valid_set's NAE: -1.41423
# [2000]	valid_set's l2: 2.36624e-05	valid_set's NAE: -1.01791
# [3000]	valid_set's l2: 2.08441e-05	valid_set's NAE: -0.898944
# [4000]	valid_set's l2: 1.96844e-05	valid_set's NAE: -0.833554
# [5000]	valid_set's l2: 1.91002e-05	valid_set's NAE: -0.798653
# [6000]	valid_set's l2: 1.8749e-05	valid_set's NAE: -0.775788
# [7000]	valid_set's l2: 1.84267e-05	valid_set's NAE: -0.760893
# [8000]	valid_set's l2: 1.82026e-05	valid_set's NAE: -0.749684
# [9000]	valid_set's l2: 1.80803e-05	valid_set's NAE: -0.745679
# [10000]	valid_set's l2: 1.79859e-05	valid_set's NAE: -0.742558
# [1000]	valid_set's l2: 3.96249e-05	valid_set's NAE: -1.39801
# [2000]	valid_set's l2: 2.83815e-05	valid_set's NAE: -1.06168
# [3000]	valid_set's l2: 2.43296e-05	valid_set's NAE: -0.931032
# [4000]	valid_set's l2: 2.22724e-05	valid_set's NAE: -0.870068
# [5000]	valid_set's l2: 2.12354e-05	valid_set's NAE: -0.825578
# [6000]	valid_set's l2: 2.04275e-05	valid_set's NAE: -0.802129
# [7000]	valid_set's l2: 1.98973e-05	valid_set's NAE: -0.782828
# [8000]	valid_set's l2: 1.95291e-05	valid_set's NAE: -0.770079
# [9000]	valid_set's l2: 1.92617e-05	valid_set's NAE: -0.76281
# [10000]	valid_set's l2: 1.90903e-05	valid_set's NAE: -0.75465
# [1000]	valid_set's l2: 5.01348e-05	valid_set's NAE: -1.38008
# [2000]	valid_set's l2: 3.40343e-05	valid_set's NAE: -1.04525
# [3000]	valid_set's l2: 2.88268e-05	valid_set's NAE: -0.933454
# [4000]	valid_set's l2: 2.66095e-05	valid_set's NAE: -0.871587
# [5000]	valid_set's l2: 2.5448e-05	valid_set's NAE: -0.828953
# [6000]	valid_set's l2: 2.48176e-05	valid_set's NAE: -0.803543
# [7000]	valid_set's l2: 2.44616e-05	valid_set's NAE: -0.788344
# [8000]	valid_set's l2: 2.42562e-05	valid_set's NAE: -0.775427
# [9000]	valid_set's l2: 2.40732e-05	valid_set's NAE: -0.766219
# [10000]	valid_set's l2: 2.38671e-05	valid_set's NAE: -0.760669
# [1000]	valid_set's l2: 3.24265e-05	valid_set's NAE: -1.31113
# [2000]	valid_set's l2: 2.16998e-05	valid_set's NAE: -0.988395
# [3000]	valid_set's l2: 1.78261e-05	valid_set's NAE: -0.856897
# [4000]	valid_set's l2: 1.63781e-05	valid_set's NAE: -0.798595
# [5000]	valid_set's l2: 1.5484e-05	valid_set's NAE: -0.764525
# [6000]	valid_set's l2: 1.49284e-05	valid_set's NAE: -0.7389
# [7000]	valid_set's l2: 1.47105e-05	valid_set's NAE: -0.721732
# [8000]	valid_set's l2: 1.45155e-05	valid_set's NAE: -0.707512
# [9000]	valid_set's l2: 1.43713e-05	valid_set's NAE: -0.702963
# [10000]	valid_set's l2: 1.42752e-05	valid_set's NAE: -0.699101
# [1000]	valid_set's l2: 3.65058e-05	valid_set's NAE: -1.34588
# [2000]	valid_set's l2: 2.53768e-05	valid_set's NAE: -0.969646
# [3000]	valid_set's l2: 2.22948e-05	valid_set's NAE: -0.850719
# [4000]	valid_set's l2: 2.10112e-05	valid_set's NAE: -0.788649
# [5000]	valid_set's l2: 2.03076e-05	valid_set's NAE: -0.758642
# [6000]	valid_set's l2: 1.97166e-05	valid_set's NAE: -0.738249
# [7000]	valid_set's l2: 1.93928e-05	valid_set's NAE: -0.721865
# [8000]	valid_set's l2: 1.91768e-05	valid_set's NAE: -0.710284
# [9000]	valid_set's l2: 1.90247e-05	valid_set's NAE: -0.701688
# [10000]	valid_set's l2: 1.8919e-05	valid_set's NAE: -0.694599
# [1000]	valid_set's l2: 3.94196e-05	valid_set's NAE: -1.39309
# [2000]	valid_set's l2: 2.77797e-05	valid_set's NAE: -1.00837
# [3000]	valid_set's l2: 2.44896e-05	valid_set's NAE: -0.895576
# [4000]	valid_set's l2: 2.32781e-05	valid_set's NAE: -0.834732
# [5000]	valid_set's l2: 2.25204e-05	valid_set's NAE: -0.803298
# [6000]	valid_set's l2: 2.21022e-05	valid_set's NAE: -0.780067
# [7000]	valid_set's l2: 2.17797e-05	valid_set's NAE: -0.765097
# [8000]	valid_set's l2: 2.16546e-05	valid_set's NAE: -0.754549
# [9000]	valid_set's l2: 2.14958e-05	valid_set's NAE: -0.745329
# [10000]	valid_set's l2: 2.13902e-05	valid_set's NAE: -0.737131
# [1000]	valid_set's l2: 2.81969e-05	valid_set's NAE: -1.31243
# [2000]	valid_set's l2: 1.87982e-05	valid_set's NAE: -0.969771
# [3000]	valid_set's l2: 1.58822e-05	valid_set's NAE: -0.862449
# [4000]	valid_set's l2: 1.46111e-05	valid_set's NAE: -0.801659
# [5000]	valid_set's l2: 1.39409e-05	valid_set's NAE: -0.770074
# [6000]	valid_set's l2: 1.34736e-05	valid_set's NAE: -0.744773
# [7000]	valid_set's l2: 1.31692e-05	valid_set's NAE: -0.732762
# [8000]	valid_set's l2: 1.29927e-05	valid_set's NAE: -0.721393
# [9000]	valid_set's l2: 1.28319e-05	valid_set's NAE: -0.713847
# [10000]	valid_set's l2: 1.27295e-05	valid_set's NAE: -0.70674
# [1000]	valid_set's l2: 3.75447e-05	valid_set's NAE: -1.32249
# [2000]	valid_set's l2: 2.67572e-05	valid_set's NAE: -0.98904
# [3000]	valid_set's l2: 2.33314e-05	valid_set's NAE: -0.881874
# [4000]	valid_set's l2: 2.18142e-05	valid_set's NAE: -0.823893
# [5000]	valid_set's l2: 2.10724e-05	valid_set's NAE: -0.78867
# [6000]	valid_set's l2: 2.04979e-05	valid_set's NAE: -0.765598
# [7000]	valid_set's l2: 2.01583e-05	valid_set's NAE: -0.751321
# [8000]	valid_set's l2: 1.98714e-05	valid_set's NAE: -0.736542
# [9000]	valid_set's l2: 1.97376e-05	valid_set's NAE: -0.728482
# [10000]	valid_set's l2: 1.96003e-05	valid_set's NAE: -0.721979
# 	-0.7271	 = Validation score   (-NAE)
# 	144.63s	 = Training   runtime
# 	2.3s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 268.08s of the 547.38s of remaining time.
# 	-0.6727	 = Validation score   (-NAE)
# 	10.04s	 = Training   runtime
# 	1.62s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 255.74s of the 535.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 2885.
# 	Ran out of time, early stopping on iteration 3035.
# 	Ran out of time, early stopping on iteration 3055.
# 	Ran out of time, early stopping on iteration 3189.
# 	Ran out of time, early stopping on iteration 3220.
# 	Ran out of time, early stopping on iteration 3426.
# 	Ran out of time, early stopping on iteration 3731.
# 	Ran out of time, early stopping on iteration 4279.
# 	-1.101	 = Validation score   (-NAE)
# 	245.2s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 10.29s of the 289.58s of remaining time.
# 	-0.5129	 = Validation score   (-NAE)
# 	4.46s	 = Training   runtime
# 	1.66s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3.60s of the 282.90s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Time limit exceeded... Skipping NeuralNetFastAI_BAG_L1.
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 3.11s of the 282.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	-10.9757	 = Validation score   (-NAE)
# 	2.85s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 0.06s of the 279.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Warning: Model has no time left to train, skipping model... (Time Left = -0.0s)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 278.87s of remaining time.
# 	Ensemble Weights: {'ExtraTreesMSE_BAG_L1': 0.647, 'LightGBM_BAG_L1': 0.176, 'LightGBMXT_BAG_L1': 0.118, 'RandomForestMSE_BAG_L1': 0.059}
# 	-0.4758	 = Validation score   (-NAE)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 278.81s of the 278.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# [1000]	valid_set's l2: 2.46191e-05	valid_set's NAE: -1.0765
# [2000]	valid_set's l2: 1.91369e-05	valid_set's NAE: -0.92381
# [3000]	valid_set's l2: 1.70434e-05	valid_set's NAE: -0.859342
# [4000]	valid_set's l2: 1.5772e-05	valid_set's NAE: -0.826351
# [5000]	valid_set's l2: 1.50185e-05	valid_set's NAE: -0.803955
# [6000]	valid_set's l2: 1.45495e-05	valid_set's NAE: -0.788415
# [7000]	valid_set's l2: 1.41573e-05	valid_set's NAE: -0.774846
# [8000]	valid_set's l2: 1.38791e-05	valid_set's NAE: -0.763062
# [9000]	valid_set's l2: 1.36684e-05	valid_set's NAE: -0.755098
# [10000]	valid_set's l2: 1.35146e-05	valid_set's NAE: -0.744829
# [1000]	valid_set's l2: 2.79914e-05	valid_set's NAE: -1.13303
# [2000]	valid_set's l2: 2.24046e-05	valid_set's NAE: -0.973433
# [3000]	valid_set's l2: 2.01694e-05	valid_set's NAE: -0.903656
# [4000]	valid_set's l2: 1.90476e-05	valid_set's NAE: -0.861948
# [5000]	valid_set's l2: 1.82315e-05	valid_set's NAE: -0.836914
# [6000]	valid_set's l2: 1.76455e-05	valid_set's NAE: -0.818208
# [7000]	valid_set's l2: 1.73142e-05	valid_set's NAE: -0.800271
# [8000]	valid_set's l2: 1.70016e-05	valid_set's NAE: -0.785643
# [9000]	valid_set's l2: 1.68248e-05	valid_set's NAE: -0.773999
# [10000]	valid_set's l2: 1.66559e-05	valid_set's NAE: -0.76369
# [1000]	valid_set's l2: 2.44284e-05	valid_set's NAE: -1.13947
# [2000]	valid_set's l2: 2.10547e-05	valid_set's NAE: -0.992185
# [3000]	valid_set's l2: 1.94621e-05	valid_set's NAE: -0.930583
# [4000]	valid_set's l2: 1.85109e-05	valid_set's NAE: -0.888729
# [5000]	valid_set's l2: 1.78962e-05	valid_set's NAE: -0.859444
# [6000]	valid_set's l2: 1.73668e-05	valid_set's NAE: -0.837217
# [7000]	valid_set's l2: 1.70122e-05	valid_set's NAE: -0.819744
# [8000]	valid_set's l2: 1.67622e-05	valid_set's NAE: -0.807246
# [9000]	valid_set's l2: 1.65649e-05	valid_set's NAE: -0.797077
# [10000]	valid_set's l2: 1.63258e-05	valid_set's NAE: -0.787108
# [1000]	valid_set's l2: 2.61332e-05	valid_set's NAE: -1.1152
# [2000]	valid_set's l2: 2.09189e-05	valid_set's NAE: -0.94954
# [3000]	valid_set's l2: 1.91367e-05	valid_set's NAE: -0.875807
# [4000]	valid_set's l2: 1.81513e-05	valid_set's NAE: -0.834466
# [5000]	valid_set's l2: 1.74932e-05	valid_set's NAE: -0.800746
# [6000]	valid_set's l2: 1.7198e-05	valid_set's NAE: -0.780898
# [7000]	valid_set's l2: 1.68726e-05	valid_set's NAE: -0.764467
# [8000]	valid_set's l2: 1.66246e-05	valid_set's NAE: -0.750585
# [9000]	valid_set's l2: 1.64357e-05	valid_set's NAE: -0.739666
# [10000]	valid_set's l2: 1.62427e-05	valid_set's NAE: -0.728156
# [1000]	valid_set's l2: 2.78872e-05	valid_set's NAE: -1.07816
# [2000]	valid_set's l2: 2.32045e-05	valid_set's NAE: -0.946862
# [3000]	valid_set's l2: 2.1228e-05	valid_set's NAE: -0.890016
# [4000]	valid_set's l2: 1.99024e-05	valid_set's NAE: -0.853045
# [5000]	valid_set's l2: 1.91369e-05	valid_set's NAE: -0.827308
# [6000]	valid_set's l2: 1.8513e-05	valid_set's NAE: -0.808234
# [7000]	valid_set's l2: 1.81626e-05	valid_set's NAE: -0.792411
# [8000]	valid_set's l2: 1.79864e-05	valid_set's NAE: -0.780253
# [9000]	valid_set's l2: 1.7808e-05	valid_set's NAE: -0.769012
# [10000]	valid_set's l2: 1.76503e-05	valid_set's NAE: -0.760766
# [1000]	valid_set's l2: 2.39321e-05	valid_set's NAE: -1.10329
# [2000]	valid_set's l2: 1.96762e-05	valid_set's NAE: -0.928897
# [3000]	valid_set's l2: 1.78333e-05	valid_set's NAE: -0.860462
# [4000]	valid_set's l2: 1.68546e-05	valid_set's NAE: -0.822623
# [5000]	valid_set's l2: 1.62446e-05	valid_set's NAE: -0.794598
# [6000]	valid_set's l2: 1.58606e-05	valid_set's NAE: -0.77724
# [7000]	valid_set's l2: 1.55662e-05	valid_set's NAE: -0.761053
# [8000]	valid_set's l2: 1.53497e-05	valid_set's NAE: -0.747449
# [9000]	valid_set's l2: 1.51938e-05	valid_set's NAE: -0.737258
# [10000]	valid_set's l2: 1.50888e-05	valid_set's NAE: -0.727965
# [1000]	valid_set's l2: 4.05889e-05	valid_set's NAE: -1.11835
# [2000]	valid_set's l2: 3.44035e-05	valid_set's NAE: -0.964126
# [3000]	valid_set's l2: 3.1139e-05	valid_set's NAE: -0.891
# [4000]	valid_set's l2: 2.90386e-05	valid_set's NAE: -0.850944
# [5000]	valid_set's l2: 2.76611e-05	valid_set's NAE: -0.823948
# [6000]	valid_set's l2: 2.64245e-05	valid_set's NAE: -0.800155
# [7000]	valid_set's l2: 2.54727e-05	valid_set's NAE: -0.785577
# [8000]	valid_set's l2: 2.46877e-05	valid_set's NAE: -0.77133
# [9000]	valid_set's l2: 2.41237e-05	valid_set's NAE: -0.761796
# [10000]	valid_set's l2: 2.36414e-05	valid_set's NAE: -0.751726
# [1000]	valid_set's l2: 3.46078e-05	valid_set's NAE: -1.16759
# [2000]	valid_set's l2: 3.26885e-05	valid_set's NAE: -0.995702
# [3000]	valid_set's l2: 3.17238e-05	valid_set's NAE: -0.909677
# [4000]	valid_set's l2: 3.08192e-05	valid_set's NAE: -0.862234
# [5000]	valid_set's l2: 3.01169e-05	valid_set's NAE: -0.827985
# [6000]	valid_set's l2: 2.95521e-05	valid_set's NAE: -0.800093
# [7000]	valid_set's l2: 2.91542e-05	valid_set's NAE: -0.779837
# [8000]	valid_set's l2: 2.87208e-05	valid_set's NAE: -0.763407
# [9000]	valid_set's l2: 2.8463e-05	valid_set's NAE: -0.753052
# [10000]	valid_set's l2: 2.82171e-05	valid_set's NAE: -0.744494
# 	-0.7511	 = Validation score   (-NAE)
# 	137.29s	 = Training   runtime
# 	2.8s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 135.56s of the 135.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# [1000]	valid_set's l2: 2.14167e-05	valid_set's NAE: -0.684011
# [1000]	valid_set's l2: 1.92718e-05	valid_set's NAE: -0.697785
# [1000]	valid_set's l2: 1.95874e-05	valid_set's NAE: -0.651812
# [2000]	valid_set's l2: 1.91323e-05	valid_set's NAE: -0.643038
# [3000]	valid_set's l2: 1.90318e-05	valid_set's NAE: -0.638954
# [4000]	valid_set's l2: 1.88394e-05	valid_set's NAE: -0.63551
# [5000]	valid_set's l2: 1.86927e-05	valid_set's NAE: -0.632691
# [6000]	valid_set's l2: 1.86534e-05	valid_set's NAE: -0.628275
# [7000]	valid_set's l2: 1.86012e-05	valid_set's NAE: -0.627628
# [8000]	valid_set's l2: 1.85439e-05	valid_set's NAE: -0.62708
# [9000]	valid_set's l2: 1.85187e-05	valid_set's NAE: -0.625804
# [10000]	valid_set's l2: 1.8497e-05	valid_set's NAE: -0.625542
# [1000]	valid_set's l2: 2.34085e-05	valid_set's NAE: -0.677676
# [1000]	valid_set's l2: 1.94459e-05	valid_set's NAE: -0.667631
# [2000]	valid_set's l2: 1.9305e-05	valid_set's NAE: -0.661425
# [3000]	valid_set's l2: 1.91784e-05	valid_set's NAE: -0.655655
# [4000]	valid_set's l2: 1.90568e-05	valid_set's NAE: -0.651189
# [5000]	valid_set's l2: 1.90075e-05	valid_set's NAE: -0.646722
# [6000]	valid_set's l2: 1.90341e-05	valid_set's NAE: -0.641116
# [7000]	valid_set's l2: 1.90399e-05	valid_set's NAE: -0.635694
# [8000]	valid_set's l2: 1.90552e-05	valid_set's NAE: -0.634863
# [9000]	valid_set's l2: 1.90368e-05	valid_set's NAE: -0.633211
# [10000]	valid_set's l2: 1.90276e-05	valid_set's NAE: -0.632367
# [1000]	valid_set's l2: 3.43101e-05	valid_set's NAE: -0.698004
# [2000]	valid_set's l2: 3.50737e-05	valid_set's NAE: -0.6902
# [3000]	valid_set's l2: 3.48755e-05	valid_set's NAE: -0.679616
# [4000]	valid_set's l2: 3.4944e-05	valid_set's NAE: -0.672996
# [5000]	valid_set's l2: 3.50202e-05	valid_set's NAE: -0.671704
# [6000]	valid_set's l2: 3.51261e-05	valid_set's NAE: -0.671746
# [7000]	valid_set's l2: 3.52097e-05	valid_set's NAE: -0.667816
# [8000]	valid_set's l2: 3.52366e-05	valid_set's NAE: -0.667041
# [9000]	valid_set's l2: 3.52406e-05	valid_set's NAE: -0.664768
# [10000]	valid_set's l2: 3.52428e-05	valid_set's NAE: -0.662763
# 	-0.6729	 = Validation score   (-NAE)
# 	71.03s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 62.03s of the 61.99s of remaining time.
# 	-0.489	 = Validation score   (-NAE)
# 	22.75s	 = Training   runtime
# 	1.77s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 36.98s of the 36.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 512.
# 	Ran out of time, early stopping on iteration 528.
# 	Ran out of time, early stopping on iteration 548.
# 	Ran out of time, early stopping on iteration 561.
# 	Ran out of time, early stopping on iteration 587.
# 	Ran out of time, early stopping on iteration 625.
# 	Ran out of time, early stopping on iteration 688.
# 	Ran out of time, early stopping on iteration 777.
# 	-1.6137	 = Validation score   (-NAE)
# 	35.35s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 1.27s of remaining time.
# 	Ensemble Weights: {'ExtraTreesMSE_BAG_L1': 0.375, 'RandomForestMSE_BAG_L2': 0.333, 'LightGBM_BAG_L1': 0.083, 'LightGBMXT_BAG_L2': 0.083, 'LightGBMXT_BAG_L1': 0.042, 'RandomForestMSE_BAG_L1': 0.042, 'LightGBM_BAG_L2': 0.042}
# 	-0.4606	 = Validation score   (-NAE)
# 	0.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 836.55s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 275.5 rows/s (2578 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("e:\Thực tập\ML cho Marketing\AutoGluon_LTV_D60\ds_sub_fit\sub_fit_ho")
# Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3      -0.407504  -0.460638         NAE       17.167845      13.782132  772.929250                 0.012093                0.001002           0.046974            3       True         12
# 1   RandomForestMSE_BAG_L2      -0.433859  -0.488973         NAE       10.558816       9.929347  564.567262                 0.474635                1.768267          22.752944            2       True         10
# 2      WeightedEnsemble_L2      -0.435455  -0.475821         NAE        9.475561       8.019227  293.807904                 0.015010                0.000000           0.039490            2       True          7
# 3          LightGBM_BAG_L2      -0.454191  -0.672934         NAE       12.306044       9.211277  612.843377                 2.221863                1.050197          71.029059            2       True          9
# 4        LightGBMXT_BAG_L2      -0.456780  -0.751068         NAE       14.459255      10.962667  679.100272                 4.375073                2.801587         137.285954            2       True          8
# 5     ExtraTreesMSE_BAG_L1      -0.478099  -0.512867         NAE        0.536507       1.662588    4.464510                 0.536507                1.662588           4.464510            1       True          5
# 6          LightGBM_BAG_L1      -0.510248  -0.727081         NAE        4.011655       2.299675  144.634289                 4.011655                2.299675         144.634289            1       True          2
# 7        LightGBMXT_BAG_L1      -0.525062  -0.798689         NAE        4.382810       2.433089  134.634056                 4.382810                2.433089         134.634056            1       True          1
# 8   RandomForestMSE_BAG_L1      -0.642395  -0.672652         NAE        0.529579       1.623876   10.035559                 0.529579                1.623876          10.035559            1       True          3
# 9          CatBoost_BAG_L1      -0.834779  -1.100964         NAE        0.261199       0.062715  245.199832                 0.261199                0.062715         245.199832            1       True          4
# 10         CatBoost_BAG_L2      -1.349099  -1.613705         NAE       10.238512       8.218044  577.159717                 0.154330                0.056964          35.345398            2       True         11
# 11          XGBoost_BAG_L1     -10.293344 -10.975709         NAE        0.362431       0.079138    2.846072                 0.362431                0.079138           2.846072            1       True          6
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	917s	 = DyStack   runtime |	2683s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 2683s
# AutoGluon will save models to "e:\Thực tập\ML cho Marketing\AutoGluon_LTV_D60"
# Train Data Rows:    23199
# Train Data Columns: 58
# Label Column:       LTV
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4507.34 MB
# 	Train Data (Original)  Memory Usage: 10.27 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['roas_d0', 'roas_d1', 'roas_d2', 'roas_d3', 'cumulative_revenue_d0', ...]
# 		('int', [])   :  6 | ['unique_users_d0', 'unique_users_d1', 'unique_users_d2', 'unique_users_d3', 'user_acceleration', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['roas_d0', 'roas_d1', 'roas_d2', 'roas_d3', 'cumulative_revenue_d0', ...]
# 		('int', [])   :  6 | ['unique_users_d0', 'unique_users_d1', 'unique_users_d2', 'unique_users_d3', 'user_acceleration', ...]
# 	0.3s = Fit runtime
# 	58 features in original data used to generate 58 features in processed data.
# 	Train Data (Processed) Memory Usage: 10.27 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 0.34s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'NAE'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1787.80s of the 2682.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# [1000]	valid_set's l2: 4.49378e-05	valid_set's NAE: -1.70539
# [2000]	valid_set's l2: 2.72039e-05	valid_set's NAE: -1.21988
# [3000]	valid_set's l2: 2.12767e-05	valid_set's NAE: -1.05031
# [4000]	valid_set's l2: 1.83909e-05	valid_set's NAE: -0.957863
# [5000]	valid_set's l2: 1.66117e-05	valid_set's NAE: -0.897245
# [6000]	valid_set's l2: 1.55325e-05	valid_set's NAE: -0.852813
# [7000]	valid_set's l2: 1.4757e-05	valid_set's NAE: -0.82244
# [8000]	valid_set's l2: 1.42667e-05	valid_set's NAE: -0.799221
# [9000]	valid_set's l2: 1.38138e-05	valid_set's NAE: -0.781367
# [10000]	valid_set's l2: 1.35e-05	valid_set's NAE: -0.766259
# [1000]	valid_set's l2: 3.85818e-05	valid_set's NAE: -1.77818
# [2000]	valid_set's l2: 2.20701e-05	valid_set's NAE: -1.21518
# [3000]	valid_set's l2: 1.77019e-05	valid_set's NAE: -1.01879
# [4000]	valid_set's l2: 1.57277e-05	valid_set's NAE: -0.924988
# [5000]	valid_set's l2: 1.44791e-05	valid_set's NAE: -0.863198
# [6000]	valid_set's l2: 1.37096e-05	valid_set's NAE: -0.824957
# [7000]	valid_set's l2: 1.30855e-05	valid_set's NAE: -0.792922
# [8000]	valid_set's l2: 1.26718e-05	valid_set's NAE: -0.768338
# [9000]	valid_set's l2: 1.23798e-05	valid_set's NAE: -0.749307
# [10000]	valid_set's l2: 1.21276e-05	valid_set's NAE: -0.733113
# [1000]	valid_set's l2: 3.84506e-05	valid_set's NAE: -1.71784
# [2000]	valid_set's l2: 2.1785e-05	valid_set's NAE: -1.23862
# [3000]	valid_set's l2: 1.69318e-05	valid_set's NAE: -1.05685
# [4000]	valid_set's l2: 1.46468e-05	valid_set's NAE: -0.960145
# [5000]	valid_set's l2: 1.32219e-05	valid_set's NAE: -0.896826
# [6000]	valid_set's l2: 1.22224e-05	valid_set's NAE: -0.851986
# [7000]	valid_set's l2: 1.15091e-05	valid_set's NAE: -0.817297
# [8000]	valid_set's l2: 1.10078e-05	valid_set's NAE: -0.789159
# [9000]	valid_set's l2: 1.06562e-05	valid_set's NAE: -0.769305
# [10000]	valid_set's l2: 1.03857e-05	valid_set's NAE: -0.751327
# [1000]	valid_set's l2: 4.35116e-05	valid_set's NAE: -1.74379
# [2000]	valid_set's l2: 2.78315e-05	valid_set's NAE: -1.24008
# [3000]	valid_set's l2: 2.33777e-05	valid_set's NAE: -1.05743
# [4000]	valid_set's l2: 2.10187e-05	valid_set's NAE: -0.95713
# [5000]	valid_set's l2: 1.97048e-05	valid_set's NAE: -0.890113
# [6000]	valid_set's l2: 1.87156e-05	valid_set's NAE: -0.840873
# [7000]	valid_set's l2: 1.80363e-05	valid_set's NAE: -0.804063
# [8000]	valid_set's l2: 1.75347e-05	valid_set's NAE: -0.780313
# [9000]	valid_set's l2: 1.70717e-05	valid_set's NAE: -0.763981
# [10000]	valid_set's l2: 1.67475e-05	valid_set's NAE: -0.748288
# [1000]	valid_set's l2: 4.34312e-05	valid_set's NAE: -1.69457
# [2000]	valid_set's l2: 2.79511e-05	valid_set's NAE: -1.22679
# [3000]	valid_set's l2: 2.30175e-05	valid_set's NAE: -1.06231
# [4000]	valid_set's l2: 2.00168e-05	valid_set's NAE: -0.970847
# [5000]	valid_set's l2: 1.80251e-05	valid_set's NAE: -0.907553
# [6000]	valid_set's l2: 1.66614e-05	valid_set's NAE: -0.863205
# [7000]	valid_set's l2: 1.56172e-05	valid_set's NAE: -0.830333
# [8000]	valid_set's l2: 1.49246e-05	valid_set's NAE: -0.80125
# [9000]	valid_set's l2: 1.43232e-05	valid_set's NAE: -0.782272
# [10000]	valid_set's l2: 1.39007e-05	valid_set's NAE: -0.766987
# [1000]	valid_set's l2: 4.2315e-05	valid_set's NAE: -1.82502
# [2000]	valid_set's l2: 2.51472e-05	valid_set's NAE: -1.29392
# [3000]	valid_set's l2: 2.00503e-05	valid_set's NAE: -1.09664
# [4000]	valid_set's l2: 1.73497e-05	valid_set's NAE: -0.986142
# [5000]	valid_set's l2: 1.56982e-05	valid_set's NAE: -0.918186
# [6000]	valid_set's l2: 1.45458e-05	valid_set's NAE: -0.877344
# [7000]	valid_set's l2: 1.37498e-05	valid_set's NAE: -0.844528
# [8000]	valid_set's l2: 1.30973e-05	valid_set's NAE: -0.819738
# [9000]	valid_set's l2: 1.26185e-05	valid_set's NAE: -0.799775
# [10000]	valid_set's l2: 1.22273e-05	valid_set's NAE: -0.783821
# [1000]	valid_set's l2: 9.26744e-05	valid_set's NAE: -1.74698
# [2000]	valid_set's l2: 7.43817e-05	valid_set's NAE: -1.23238
# [3000]	valid_set's l2: 6.71982e-05	valid_set's NAE: -1.04266
# [4000]	valid_set's l2: 6.32462e-05	valid_set's NAE: -0.945322
# [5000]	valid_set's l2: 6.12284e-05	valid_set's NAE: -0.887336
# [6000]	valid_set's l2: 5.94356e-05	valid_set's NAE: -0.846323
# [7000]	valid_set's l2: 5.83862e-05	valid_set's NAE: -0.815992
# [8000]	valid_set's l2: 5.78645e-05	valid_set's NAE: -0.79335
# [9000]	valid_set's l2: 5.71686e-05	valid_set's NAE: -0.776804
# [10000]	valid_set's l2: 5.67817e-05	valid_set's NAE: -0.761571
# [1000]	valid_set's l2: 3.95684e-05	valid_set's NAE: -1.75304
# [2000]	valid_set's l2: 2.22683e-05	valid_set's NAE: -1.24177
# [3000]	valid_set's l2: 1.72998e-05	valid_set's NAE: -1.05327
# [4000]	valid_set's l2: 1.50983e-05	valid_set's NAE: -0.965047
# [5000]	valid_set's l2: 1.37215e-05	valid_set's NAE: -0.917119
# [6000]	valid_set's l2: 1.29512e-05	valid_set's NAE: -0.874123
# [7000]	valid_set's l2: 1.23638e-05	valid_set's NAE: -0.847537
# [8000]	valid_set's l2: 1.19563e-05	valid_set's NAE: -0.825965
# [9000]	valid_set's l2: 1.15746e-05	valid_set's NAE: -0.803164
# [10000]	valid_set's l2: 1.13079e-05	valid_set's NAE: -0.786221
# 	-0.7621	 = Validation score   (-NAE)
# 	141.1s	 = Training   runtime
# 	2.77s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1640.87s of the 2535.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# [1000]	valid_set's l2: 2.71955e-05	valid_set's NAE: -1.24515
# [2000]	valid_set's l2: 1.85125e-05	valid_set's NAE: -0.931326
# [3000]	valid_set's l2: 1.56782e-05	valid_set's NAE: -0.795795
# [4000]	valid_set's l2: 1.45349e-05	valid_set's NAE: -0.743509
# [5000]	valid_set's l2: 1.39221e-05	valid_set's NAE: -0.713621
# [6000]	valid_set's l2: 1.35142e-05	valid_set's NAE: -0.691834
# [7000]	valid_set's l2: 1.3242e-05	valid_set's NAE: -0.677011
# [8000]	valid_set's l2: 1.30563e-05	valid_set's NAE: -0.662758
# [9000]	valid_set's l2: 1.29228e-05	valid_set's NAE: -0.654695
# [10000]	valid_set's l2: 1.28358e-05	valid_set's NAE: -0.64889
# [1000]	valid_set's l2: 2.94759e-05	valid_set's NAE: -1.27978
# [2000]	valid_set's l2: 1.89424e-05	valid_set's NAE: -0.944658
# [3000]	valid_set's l2: 1.57197e-05	valid_set's NAE: -0.821208
# [4000]	valid_set's l2: 1.42772e-05	valid_set's NAE: -0.747075
# [5000]	valid_set's l2: 1.34653e-05	valid_set's NAE: -0.712327
# [6000]	valid_set's l2: 1.29916e-05	valid_set's NAE: -0.683752
# [7000]	valid_set's l2: 1.26914e-05	valid_set's NAE: -0.663364
# [8000]	valid_set's l2: 1.25217e-05	valid_set's NAE: -0.652565
# [9000]	valid_set's l2: 1.23808e-05	valid_set's NAE: -0.642142
# [10000]	valid_set's l2: 1.22681e-05	valid_set's NAE: -0.635762
# [1000]	valid_set's l2: 2.76816e-05	valid_set's NAE: -1.31453
# [2000]	valid_set's l2: 1.78231e-05	valid_set's NAE: -0.946879
# [3000]	valid_set's l2: 1.50875e-05	valid_set's NAE: -0.81956
# [4000]	valid_set's l2: 1.39327e-05	valid_set's NAE: -0.757924
# [5000]	valid_set's l2: 1.33384e-05	valid_set's NAE: -0.724283
# [6000]	valid_set's l2: 1.2893e-05	valid_set's NAE: -0.697566
# [7000]	valid_set's l2: 1.26437e-05	valid_set's NAE: -0.684438
# [8000]	valid_set's l2: 1.24443e-05	valid_set's NAE: -0.675312
# [9000]	valid_set's l2: 1.22789e-05	valid_set's NAE: -0.666266
# [10000]	valid_set's l2: 1.21777e-05	valid_set's NAE: -0.661494
# [1000]	valid_set's l2: 3.08873e-05	valid_set's NAE: -1.30397
# [2000]	valid_set's l2: 2.19162e-05	valid_set's NAE: -0.950136
# [3000]	valid_set's l2: 1.94859e-05	valid_set's NAE: -0.827628
# [4000]	valid_set's l2: 1.81068e-05	valid_set's NAE: -0.759827
# [5000]	valid_set's l2: 1.7306e-05	valid_set's NAE: -0.727214
# [6000]	valid_set's l2: 1.66551e-05	valid_set's NAE: -0.705093
# [7000]	valid_set's l2: 1.62849e-05	valid_set's NAE: -0.689348
# [8000]	valid_set's l2: 1.60231e-05	valid_set's NAE: -0.676243
# [9000]	valid_set's l2: 1.58478e-05	valid_set's NAE: -0.669037
# [10000]	valid_set's l2: 1.57268e-05	valid_set's NAE: -0.660973
# [1000]	valid_set's l2: 3.30814e-05	valid_set's NAE: -1.30942
# [2000]	valid_set's l2: 2.16581e-05	valid_set's NAE: -0.964514
# [3000]	valid_set's l2: 1.85574e-05	valid_set's NAE: -0.826108
# [4000]	valid_set's l2: 1.71538e-05	valid_set's NAE: -0.765
# [5000]	valid_set's l2: 1.62739e-05	valid_set's NAE: -0.727782
# [6000]	valid_set's l2: 1.58643e-05	valid_set's NAE: -0.706918
# [7000]	valid_set's l2: 1.55884e-05	valid_set's NAE: -0.693307
# [8000]	valid_set's l2: 1.53806e-05	valid_set's NAE: -0.682917
# [9000]	valid_set's l2: 1.52253e-05	valid_set's NAE: -0.675564
# [10000]	valid_set's l2: 1.51239e-05	valid_set's NAE: -0.669967
# [1000]	valid_set's l2: 3.00113e-05	valid_set's NAE: -1.36702
# [2000]	valid_set's l2: 1.96674e-05	valid_set's NAE: -1.00734
# [3000]	valid_set's l2: 1.64054e-05	valid_set's NAE: -0.877718
# [4000]	valid_set's l2: 1.50159e-05	valid_set's NAE: -0.813842
# [5000]	valid_set's l2: 1.43522e-05	valid_set's NAE: -0.774824
# [6000]	valid_set's l2: 1.38971e-05	valid_set's NAE: -0.750914
# [7000]	valid_set's l2: 1.36864e-05	valid_set's NAE: -0.736477
# [8000]	valid_set's l2: 1.35268e-05	valid_set's NAE: -0.724665
# [9000]	valid_set's l2: 1.3382e-05	valid_set's NAE: -0.716605
# [10000]	valid_set's l2: 1.33032e-05	valid_set's NAE: -0.710978
# [1000]	valid_set's l2: 7.82676e-05	valid_set's NAE: -1.31409
# [2000]	valid_set's l2: 6.61671e-05	valid_set's NAE: -0.977297
# [3000]	valid_set's l2: 6.27573e-05	valid_set's NAE: -0.85938
# [4000]	valid_set's l2: 6.15026e-05	valid_set's NAE: -0.800485
# [5000]	valid_set's l2: 6.09069e-05	valid_set's NAE: -0.755986
# [6000]	valid_set's l2: 6.05064e-05	valid_set's NAE: -0.736401
# [7000]	valid_set's l2: 6.04389e-05	valid_set's NAE: -0.720409
# [8000]	valid_set's l2: 6.02906e-05	valid_set's NAE: -0.708566
# [9000]	valid_set's l2: 6.01783e-05	valid_set's NAE: -0.698597
# [10000]	valid_set's l2: 6.01478e-05	valid_set's NAE: -0.693708
# [1000]	valid_set's l2: 2.9145e-05	valid_set's NAE: -1.35562
# [2000]	valid_set's l2: 2.06338e-05	valid_set's NAE: -1.0109
# [3000]	valid_set's l2: 1.82388e-05	valid_set's NAE: -0.88923
# [4000]	valid_set's l2: 1.69097e-05	valid_set's NAE: -0.815868
# [5000]	valid_set's l2: 1.62215e-05	valid_set's NAE: -0.788712
# [6000]	valid_set's l2: 1.58943e-05	valid_set's NAE: -0.770688
# [7000]	valid_set's l2: 1.57272e-05	valid_set's NAE: -0.757768
# [8000]	valid_set's l2: 1.56009e-05	valid_set's NAE: -0.74764
# [9000]	valid_set's l2: 1.54951e-05	valid_set's NAE: -0.739353
# [10000]	valid_set's l2: 1.54194e-05	valid_set's NAE: -0.73206
# 	-0.6767	 = Validation score   (-NAE)
# 	165.43s	 = Training   runtime
# 	2.75s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 1469.54s of the 2364.10s of remaining time.
# 	-0.6084	 = Validation score   (-NAE)
# 	12.61s	 = Training   runtime
# 	2.0s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1454.31s of the 2348.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	-0.7097	 = Validation score   (-NAE)
# 	1190.45s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 263.49s of the 1158.05s of remaining time.
# 	-0.4655	 = Validation score   (-NAE)
# 	4.92s	 = Training   runtime
# 	1.79s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 256.16s of the 1150.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# Metric NAE is not supported by this model - using mean_squared_error instead
# Metric NAE is not supported by this model - using mean_squared_error instead
# Metric NAE is not supported by this model - using mean_squared_error instead
# Metric NAE is not supported by this model - using mean_squared_error instead
# Metric NAE is not supported by this model - using mean_squared_error instead
# Metric NAE is not supported by this model - using mean_squared_error instead
# Metric NAE is not supported by this model - using mean_squared_error instead
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	-9.571	 = Validation score   (-NAE)
# 	132.0s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 123.63s of the 1018.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	-1.2155	 = Validation score   (-NAE)
# 	32.34s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 90.86s of the 985.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, stopping training early. (Stopping on epoch 24)
# 	Ran out of time, stopping training early. (Stopping on epoch 21)
# 	Ran out of time, stopping training early. (Stopping on epoch 25)
# 	Ran out of time, stopping training early. (Stopping on epoch 27)
# 	Ran out of time, stopping training early. (Stopping on epoch 28)
# 	Ran out of time, stopping training early. (Stopping on epoch 31)
# 	Ran out of time, stopping training early. (Stopping on epoch 35)
# 	Ran out of time, stopping training early. (Stopping on epoch 38)
# 	-6.4443	 = Validation score   (-NAE)
# 	86.32s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 3.98s of the 898.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 7. Best iteration is:
# 	[7]	valid_set's l2: 0.0970545	valid_set's NAE: -157.28
# 	Ran out of time, early stopping on iteration 13. Best iteration is:
# 	[13]	valid_set's l2: 0.0740581	valid_set's NAE: -135.98
# 	Ran out of time, early stopping on iteration 13. Best iteration is:
# 	[13]	valid_set's l2: 0.0708489	valid_set's NAE: -131.626
# 	Ran out of time, early stopping on iteration 16. Best iteration is:
# 	[16]	valid_set's l2: 0.0588508	valid_set's NAE: -126.596
# 	Ran out of time, early stopping on iteration 14. Best iteration is:
# 	[14]	valid_set's l2: 0.0678661	valid_set's NAE: -123.541
# 	Ran out of time, early stopping on iteration 21. Best iteration is:
# 	[21]	valid_set's l2: 0.0450916	valid_set's NAE: -107.918
# 	Ran out of time, early stopping on iteration 23. Best iteration is:
# 	[23]	valid_set's l2: 0.0399269	valid_set's NAE: -101.711
# 	Ran out of time, early stopping on iteration 33. Best iteration is:
# 	[33]	valid_set's l2: 0.0210381	valid_set's NAE: -76.1018
# 	-120.0963	 = Validation score   (-NAE)
# 	3.75s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 0.11s of the 894.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Warning: Model has no time left to train, skipping model... (Time Left = -0.0s)
# 	Time limit exceeded... Skipping CatBoost_r177_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 894.21s of remaining time.
# 	Ensemble Weights: {'ExtraTreesMSE_BAG_L1': 0.6, 'LightGBM_BAG_L1': 0.12, 'CatBoost_BAG_L1': 0.12, 'LightGBMXT_BAG_L1': 0.08, 'RandomForestMSE_BAG_L1': 0.08}
# 	-0.4326	 = Validation score   (-NAE)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 894.16s of the 894.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# [1000]	valid_set's l2: 2.35137e-05	valid_set's NAE: -1.08813
# [2000]	valid_set's l2: 1.94188e-05	valid_set's NAE: -0.943316
# [3000]	valid_set's l2: 1.75397e-05	valid_set's NAE: -0.877426
# [4000]	valid_set's l2: 1.64953e-05	valid_set's NAE: -0.83431
# [5000]	valid_set's l2: 1.5807e-05	valid_set's NAE: -0.807262
# [6000]	valid_set's l2: 1.5299e-05	valid_set's NAE: -0.783644
# [7000]	valid_set's l2: 1.49423e-05	valid_set's NAE: -0.764814
# [8000]	valid_set's l2: 1.4635e-05	valid_set's NAE: -0.75175
# [9000]	valid_set's l2: 1.4312e-05	valid_set's NAE: -0.739565
# [10000]	valid_set's l2: 1.41251e-05	valid_set's NAE: -0.731082
# [1000]	valid_set's l2: 2.21152e-05	valid_set's NAE: -1.11816
# [2000]	valid_set's l2: 1.80504e-05	valid_set's NAE: -0.956449
# [3000]	valid_set's l2: 1.66046e-05	valid_set's NAE: -0.894123
# [4000]	valid_set's l2: 1.5812e-05	valid_set's NAE: -0.857513
# [5000]	valid_set's l2: 1.51899e-05	valid_set's NAE: -0.829996
# [6000]	valid_set's l2: 1.46964e-05	valid_set's NAE: -0.809636
# [7000]	valid_set's l2: 1.43573e-05	valid_set's NAE: -0.792067
# [8000]	valid_set's l2: 1.41049e-05	valid_set's NAE: -0.778253
# [9000]	valid_set's l2: 1.39236e-05	valid_set's NAE: -0.767465
# [10000]	valid_set's l2: 1.37509e-05	valid_set's NAE: -0.756818
# [1000]	valid_set's l2: 2.57341e-05	valid_set's NAE: -1.0369
# [2000]	valid_set's l2: 2.10815e-05	valid_set's NAE: -0.918104
# [3000]	valid_set's l2: 1.92852e-05	valid_set's NAE: -0.859408
# [4000]	valid_set's l2: 1.83119e-05	valid_set's NAE: -0.822662
# [5000]	valid_set's l2: 1.74965e-05	valid_set's NAE: -0.791051
# [6000]	valid_set's l2: 1.70899e-05	valid_set's NAE: -0.771324
# [7000]	valid_set's l2: 1.67241e-05	valid_set's NAE: -0.753849
# [8000]	valid_set's l2: 1.63934e-05	valid_set's NAE: -0.739092
# [9000]	valid_set's l2: 1.61683e-05	valid_set's NAE: -0.72812
# [10000]	valid_set's l2: 1.59731e-05	valid_set's NAE: -0.71877
# [1000]	valid_set's l2: 8.53608e-05	valid_set's NAE: -1.10696
# [2000]	valid_set's l2: 7.93109e-05	valid_set's NAE: -0.958057
# [3000]	valid_set's l2: 7.71951e-05	valid_set's NAE: -0.889332
# [4000]	valid_set's l2: 7.54581e-05	valid_set's NAE: -0.850393
# [5000]	valid_set's l2: 7.38599e-05	valid_set's NAE: -0.825031
# [6000]	valid_set's l2: 7.26084e-05	valid_set's NAE: -0.804606
# [7000]	valid_set's l2: 7.17287e-05	valid_set's NAE: -0.787332
# [8000]	valid_set's l2: 7.12077e-05	valid_set's NAE: -0.775765
# [9000]	valid_set's l2: 7.05656e-05	valid_set's NAE: -0.763435
# [10000]	valid_set's l2: 6.999e-05	valid_set's NAE: -0.755205
# [1000]	valid_set's l2: 2.49315e-05	valid_set's NAE: -1.16536
# [2000]	valid_set's l2: 2.046e-05	valid_set's NAE: -0.993381
# [3000]	valid_set's l2: 1.86134e-05	valid_set's NAE: -0.91674
# [4000]	valid_set's l2: 1.74103e-05	valid_set's NAE: -0.867772
# [5000]	valid_set's l2: 1.6688e-05	valid_set's NAE: -0.835126
# [6000]	valid_set's l2: 1.62109e-05	valid_set's NAE: -0.807312
# [7000]	valid_set's l2: 1.58051e-05	valid_set's NAE: -0.78749
# [8000]	valid_set's l2: 1.54871e-05	valid_set's NAE: -0.772713
# [9000]	valid_set's l2: 1.52478e-05	valid_set's NAE: -0.759497
# [10000]	valid_set's l2: 1.50187e-05	valid_set's NAE: -0.750476
# [1000]	valid_set's l2: 2.40687e-05	valid_set's NAE: -1.1066
# [2000]	valid_set's l2: 1.92279e-05	valid_set's NAE: -0.956677
# [3000]	valid_set's l2: 1.74006e-05	valid_set's NAE: -0.885143
# [4000]	valid_set's l2: 1.63911e-05	valid_set's NAE: -0.846664
# [5000]	valid_set's l2: 1.57172e-05	valid_set's NAE: -0.821229
# [6000]	valid_set's l2: 1.51867e-05	valid_set's NAE: -0.803697
# [7000]	valid_set's l2: 1.4792e-05	valid_set's NAE: -0.786073
# [8000]	valid_set's l2: 1.44503e-05	valid_set's NAE: -0.772843
# [9000]	valid_set's l2: 1.41817e-05	valid_set's NAE: -0.763144
# [10000]	valid_set's l2: 1.39417e-05	valid_set's NAE: -0.753377
# [1000]	valid_set's l2: 2.56343e-05	valid_set's NAE: -1.09832
# [2000]	valid_set's l2: 2.11044e-05	valid_set's NAE: -0.943004
# [3000]	valid_set's l2: 1.94273e-05	valid_set's NAE: -0.871897
# [4000]	valid_set's l2: 1.87214e-05	valid_set's NAE: -0.832608
# [5000]	valid_set's l2: 1.8198e-05	valid_set's NAE: -0.80378
# [6000]	valid_set's l2: 1.79039e-05	valid_set's NAE: -0.783682
# [7000]	valid_set's l2: 1.76432e-05	valid_set's NAE: -0.767122
# [8000]	valid_set's l2: 1.73289e-05	valid_set's NAE: -0.754062
# [9000]	valid_set's l2: 1.71745e-05	valid_set's NAE: -0.742186
# [10000]	valid_set's l2: 1.69805e-05	valid_set's NAE: -0.733729
# [1000]	valid_set's l2: 2.29549e-05	valid_set's NAE: -1.09869
# [2000]	valid_set's l2: 1.87346e-05	valid_set's NAE: -0.963305
# [3000]	valid_set's l2: 1.72107e-05	valid_set's NAE: -0.891798
# [4000]	valid_set's l2: 1.63299e-05	valid_set's NAE: -0.854233
# [5000]	valid_set's l2: 1.58131e-05	valid_set's NAE: -0.824726
# [6000]	valid_set's l2: 1.54695e-05	valid_set's NAE: -0.805281
# [7000]	valid_set's l2: 1.51351e-05	valid_set's NAE: -0.787451
# [8000]	valid_set's l2: 1.49365e-05	valid_set's NAE: -0.77683
# [9000]	valid_set's l2: 1.48397e-05	valid_set's NAE: -0.765703
# [10000]	valid_set's l2: 1.46655e-05	valid_set's NAE: -0.755762
# 	-0.7444	 = Validation score   (-NAE)
# 	155.39s	 = Training   runtime
# 	3.28s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 732.16s of the 732.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# [1000]	valid_set's l2: 1.54226e-05	valid_set's NAE: -0.653821
# [1000]	valid_set's l2: 5.82778e-05	valid_set's NAE: -0.66989
# [1000]	valid_set's l2: 1.57098e-05	valid_set's NAE: -0.649907
# [1000]	valid_set's l2: 1.66018e-05	valid_set's NAE: -0.635189
# [2000]	valid_set's l2: 1.69325e-05	valid_set's NAE: -0.63049
# [1000]	valid_set's l2: 1.71155e-05	valid_set's NAE: -0.64525
# 	-0.6422	 = Validation score   (-NAE)
# 	27.64s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 703.86s of the 703.84s of remaining time.
# 	-0.4472	 = Validation score   (-NAE)
# 	30.17s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 671.31s of the 671.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 5810.
# 	Ran out of time, early stopping on iteration 5707.
# 	Ran out of time, early stopping on iteration 6166.
# 	Ran out of time, early stopping on iteration 6212.
# 	Ran out of time, early stopping on iteration 6429.
# 	Ran out of time, early stopping on iteration 6723.
# 	Ran out of time, early stopping on iteration 7440.
# 	Ran out of time, early stopping on iteration 8045.
# 	-0.7171	 = Validation score   (-NAE)
# 	643.8s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 27.21s of the 27.18s of remaining time.
# 	-0.4313	 = Validation score   (-NAE)
# 	8.22s	 = Training   runtime
# 	1.8s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 16.63s of the 16.60s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Ran out of time, stopping training early. (Stopping on epoch 1)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Ran out of time, stopping training early. (Stopping on epoch 1)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Ran out of time, stopping training early. (Stopping on epoch 1)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Ran out of time, stopping training early. (Stopping on epoch 2)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Ran out of time, stopping training early. (Stopping on epoch 2)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Ran out of time, stopping training early. (Stopping on epoch 2)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Ran out of time, stopping training early. (Stopping on epoch 3)
# Metric NAE is not supported by this model - using mean_squared_error instead
# 	Ran out of time, stopping training early. (Stopping on epoch 5)
# 	-12.1584	 = Validation score   (-NAE)
# 	15.26s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 0.79s of remaining time.
# 	Ensemble Weights: {'ExtraTreesMSE_BAG_L2': 0.5, 'ExtraTreesMSE_BAG_L1': 0.333, 'LightGBM_BAG_L1': 0.042, 'CatBoost_BAG_L1': 0.042, 'LightGBMXT_BAG_L2': 0.042, 'RandomForestMSE_BAG_L2': 0.042}
# 	-0.4192	 = Validation score   (-NAE)
# 	0.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2682.02s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 271.3 rows/s (2900 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("e:\Thực tập\ML cho Marketing\AutoGluon_LTV_D60")
# --- AutoGluon đã hoàn tất huấn luyện! ---

# %%
X_test_input = test_data.drop(columns=['LTV'])
y_pred = predictor.predict(X_test_input)

test_data["pre_nae"] = 100* np.abs(test_data["LTV"] - y_pred) / (np.abs(test_data["LTV"]) + eps)
mae_by_day = test_data.groupby('Day')['pre_nae'].mean().reset_index()
mae_by_day.rename(columns={'pre_nae': 'NAE'}, inplace=True)

print(mae_by_day)
# Out:
#     Day        NAE
# 0     4   4.069788
# 1     5   4.796543
# 2     6   5.404289
# 3     7   6.135445
# 4     8   6.447680
# 5     9   6.932190
# 6    10   7.050550
# 7    11   7.287006
# 8    12   7.672455
# 9    13   7.917473
# 10   14   8.194911
# 11   15   8.511490
# 12   16   8.831794
# 13   17   9.295538
# 14   18   9.509186
# 15   19   9.729783
# 16   20  10.085205
# 17   21  10.484871
# 18   22  10.872049
# 19   23  11.134427
# 20   24  11.426585
# 21   25  11.680832
# 22   26  11.823627
# 23   27  11.959119
# 24   28  12.182942
# 25   29  12.282060
# 26   30  12.416905
# 27   31  12.629766
# 28   32  12.820678
# 29   33  12.982271
# 30   34  13.139633
# 31   35  13.308281
# 32   36  13.450398
# 33   37  13.502838
# 34   38  13.617318
# 35   39  13.767979
# 36   40  13.840447
# 37   41  13.938929
# 38   42  14.075051
# 39   43  14.218034
# 40   44  14.370665
# 41   45  14.442772
# 42   46  14.616061
# 43   47  14.750430
# 44   48  14.839564
# 45   49  14.906032
# 46   50  14.952855
# 47   51  15.060642
# 48   52  15.136692
# 49   53  15.184188
# 50   54  15.281330
# 51   55  15.321416
# 52   56  15.345849
# 53   57  15.581047
# 54   58  15.697099
# 55   59  15.757369
# 56   60  15.824586

# %%
y_pred_autogluon = predictor.predict(test_data.drop(columns=["LTV"]))

predictor.evaluate(test_data, silent=True) 

leaderboard = predictor.leaderboard(test_data, silent=True)
print("\n--- Bảng xếp hạng các mô hình tự động ---")
print(leaderboard)
# Out:
# --- Bảng xếp hạng các mô hình tự động ---
#                      model  score_test   score_val eval_metric  \
# 0   RandomForestMSE_BAG_L2  -11.671582   -0.447187         NAE
# 1      WeightedEnsemble_L3  -11.868333   -0.419216         NAE
# 2     ExtraTreesMSE_BAG_L2  -11.888331   -0.431292         NAE
# 3      WeightedEnsemble_L2  -11.923858   -0.432650         NAE
# 4          LightGBM_BAG_L2  -12.051697   -0.642188         NAE
# 5          CatBoost_BAG_L2  -12.134461   -0.717130         NAE
# 6     ExtraTreesMSE_BAG_L1  -12.144745   -0.465497         NAE
# 7        LightGBMXT_BAG_L2  -12.333209   -0.744387         NAE
# 8        LightGBMXT_BAG_L1  -12.400510   -0.762105         NAE
# 9          LightGBM_BAG_L1  -12.474995   -0.676652         NAE
# 10         CatBoost_BAG_L1  -13.024370   -0.709670         NAE
# 11          XGBoost_BAG_L1  -13.147452   -1.215476         NAE
# 12   NeuralNetTorch_BAG_L1  -13.662168   -6.444264         NAE
# 13  RandomForestMSE_BAG_L1  -13.845682   -0.608404         NAE
# 14  NeuralNetFastAI_BAG_L1  -15.993010   -9.571039         NAE
# 15  NeuralNetFastAI_BAG_L2  -16.770078  -12.158427         NAE
# 16    LightGBMLarge_BAG_L1 -136.379220 -120.096299         NAE
#
#     pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 0        17.398907      12.103225  1799.075660                 0.550675
# 1        25.663474      17.183438  1962.762648                 0.004208
# 2        17.424495      12.070827  1777.132627                 0.576263
# 3        15.180039       9.403941  1514.540372                 0.019020
# 4        17.922063      10.478764  1796.549179                 1.073831
# 5        17.173962      10.346785  2412.707727                 0.325730
# 6         0.520802       1.793082     4.916274                 0.520802
# 7        24.532329      13.555588  1924.302718                 7.684097
# 8         7.345693       2.772004   141.095187                 7.345693
# 9         6.332752       2.751924   165.434877                 6.332752
# 10        0.406561       0.084431  1190.445653                 0.406561
# 11        0.465976       0.186778    32.337386                 0.465976
# 12        0.683902       0.428741    86.319239                 0.683902
# 13        0.555211       2.002500    12.606545                 0.555211
# 14        0.498803       0.240635   131.999466                 0.498803
# 15       17.696751      10.520491  1784.165692                 0.848519
# 16        0.038532       0.013006     3.754880                 0.038532
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 1.830124          30.166153            2       True
# 1                 0.000000           0.070657            3       True
# 2                 1.797725           8.223120            2       True
# 3                 0.000000           0.041836            2       True
# 4                 0.205663          27.639672            2       True
# 5                 0.073684         643.798220            2       True
# 6                 1.793082           4.916274            1       True
# 7                 3.282487         155.393211            2       True
# 8                 2.772004         141.095187            1       True
# 9                 2.751924         165.434877            1       True
# 10                0.084431        1190.445653            1       True
# 11                0.186778          32.337386            1       True
# 12                0.428741          86.319239            1       True
# 13                2.002500          12.606545            1       True
# 14                0.240635         131.999466            1       True
# 15                0.247390          15.256185            2       True
# 16                0.013006           3.754880            1       True
#
#     fit_order
# 0          13
# 1          17
# 2          15
# 3          10
# 4          12
# 5          14
# 6           5
# 7          11
# 8           1
# 9           2
# 10          4
# 11          7
# 12          8
# 13          3
# 14          6
# 15         16
# 16          9

# %% [markdown]
#           Day        NAE
# 0    3.084288   3.971061
# 1    3.722591   4.699986
# 2    4.333314   5.325197
# 3    4.921379   6.120727
# 4    5.490327   6.485921
# 5    6.042813   6.928712
# 6    6.580898   7.075751
# 7    7.106221   7.369742
# 8    7.620115   7.687313
# 9    8.123682   7.941926
# 10   8.617846   8.175557
# 11   9.103394   8.527441
# 12   9.581002   8.864384
# 13  10.051256   9.259032
# 14  10.514669   9.447124
# 15  10.971694   9.707706
# 16  11.422731  10.069434
# 17  11.868140  10.412576
# 18  12.308241  10.764021
# 19  12.743324  11.062590
# 20  13.173654  11.254207
# 21  13.599468  11.503503
# 22  14.020985  11.649880
# 23  14.438406  11.796686
# 24  14.851914  12.009804
# 25  15.261680  12.120289
# 26  15.667860  12.263903
# 27  16.070600  12.525885
# 28  16.470035  12.719469
# 29  16.866291  12.935356
# 30  17.259487  13.115681
# 31  17.649731  13.254639
# 32  18.037128  13.391835
# 33  18.421774  13.492484
# 34  18.803761  13.619953
# 35  19.183174  13.746165
# 36  19.560094  13.881528
# 37  19.934599  13.971727
# 38  20.306760  14.121200
# 39  20.676646  14.249872
# 40  21.044322  14.373244
# 41  21.409851  14.436997
# 42  21.773291  14.596118
# 43  22.134697  14.695176
# 44  22.494124  14.801711
# 45  22.851623  14.859983
# 46  23.207241  14.919175
# 47  23.561026  14.998386
# 48  23.913022  15.066283
# 49  24.263271  15.101228
# 50  24.611814  15.176045
# 51  24.958691  15.223690
# 52  25.303939  15.237406
# 53  25.647593  15.478252
# 54  25.989689  15.576702
# 55  26.330259  15.661039
# 56  26.669337  15.692962
